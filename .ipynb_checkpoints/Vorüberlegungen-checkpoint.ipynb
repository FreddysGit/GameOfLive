# %% [markdown]
# #Vorüberlegungen

# %% [markdown]
# ##Benutzereingabe

# %% [markdown]
# - Über eine Textdatei
# - feste Reihenfoleg der Parameter
# - untereinander geschrieben
# - u.U. Möglichkeit, diese vorzubereiten

# %% [markdown]
# ##Systemgröße

# %% [markdown]
# Länge und Breite

# %% [markdown]
# ##Randbedingungen

# %% [markdown]
# - periodisch
# - begrenzt
#     - Rand bedeutet Ende Zellen dahinter "verschwinden"

# %% [markdown]
# ##Anfangsbedingungen

# %% [markdown]
# Liste von Zellen-Positionen, welche am Anfang vorhanden sein sollen
# - Position wie Matrixkoordinate

# %% [markdown]
# ##Regelstring

# %% [markdown]
# wie beschrieben

# %% [markdown]
# ##Fehlermeldungen

# %% [markdown]
# Fehlermeldungen für verschiedene Fälle, wie z.B.
# - Anfangsbedingungen außerhalb der Matrix
# - Falsche Benutzereingabe
# - ...
